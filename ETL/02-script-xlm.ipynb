# %%
from pikepdf import Pdf
from pathlib import Path
pdf_path = Path(r"C:\Users\yamak\Desktop\Portafolio\Proyecto 01\Finanzas personales\PDF Fix\04-Abril.pdf")
pdf = Pdf.open(pdf_path)
for nombre, archivo in pdf.attachments.items():
    print(f"Archivo adjunto: {nombre}")
