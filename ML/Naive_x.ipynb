# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix
from pathlib import Path
import pandas as pd


file_path = Path('C:/Users/yamak/Desktop/Portafolio/Proyecto 01/Finanzas personales/CSV/todas_las_tablas_limpias_v2.csv')
df = pd.read_csv(file_path)
nb = MultinomialNB()

# %%
# texto en minusculas y sin puntuación

df["Descripcion"] = df["Descripcion"].str.lower().str.replace('[^\w\s]', ' ', regex=True)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\yamak\AppData\Local\Temp\ipykernel_41092\3781118098.py:3: SyntaxWarning: invalid escape sequence '\w'
#   df["Descripcion"] = df["Descripcion"].str.lower().str.replace('[^\w\s]', ' ', regex=True)

# %%
# Dividir en train y test
X_train, X_test, y_train, y_test = train_test_split(
    df["Descripcion"], df["Categoria movimiento"], test_size=0.2, random_state=42
)

# Vectorizar texto
vectorizer = TfidfVectorizer(max_features=3000, stop_words="spanish")
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[12], line 8
#       6 # Vectorizar texto
#       7 vectorizer = TfidfVectorizer(max_features=3000, stop_words="spanish")
# ----> 8 X_train_tfidf = vectorizer.fit_transform(X_train)
#       9 X_test_tfidf = vectorizer.transform(X_test)
#
# File c:\Users\yamak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\feature_extraction\text.py:2105, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2098 self._check_params()
#    2099 self._tfidf = TfidfTransformer(
#    2100     norm=self.norm,
#    2101     use_idf=self.use_idf,
#    2102     smooth_idf=self.smooth_idf,
#    2103     sublinear_tf=self.sublinear_tf,
#    2104 )
# -> 2105 X = super().fit_transform(raw_documents)
#    2106 self._tfidf.fit(X)
#    2107 # X is already a transformed view of raw_documents so
#    2108 # we set copy to False
#
# ...

# %%
nb = MultinomialNB()
nb.fit(X_train_tfidf, y_train)

# %%
y_pred = nb.predict(X_test_tfidf)

# Reporte de métricas
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
